# %%
import spacy

# %%
doc = nlp(''' "Let's go to N.Y!" ''')

for token in doc:
    print(token)
# Out:
#
# "
# Let
# 's
# go
# to
# N.Y
# !
# "

# %%
nlp = spacy.blank("en")

doc = nlp("Dr.Strange is a great movie. I like it.")

for token in doc:
    print(token)
# Out:
# Dr.
# Strange
# is
# a
# great
# movie
# .
# I
# like
# it
# .

# %%
span = doc[1:5]
# Out:
# Strange is a great

# %%
doc[-1]
# Out:
# .

# %%
type(nlp)
# Out:
# spacy.lang.en.English

# %%
type(doc)
# Out:
# spacy.tokens.doc.Doc

# %%
type(token)
# Out:
# spacy.tokens.token.Token

# %%
doc = nlp("Tony gave two $ to Peter.")

# %%
token0 = doc[0]
token0
# Out:
# Tony

# %%
type(token0)
# Out:
# spacy.tokens.token.Token

# %%
dir(token0)
# Out:
# ['_',
#  '__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  'ancestors',
#  'check_flag',
#  'children',
#  'cluster',
#  'conjuncts',
#  'dep',
#  'dep_',
#  'doc',
#  'ent_id',
#  'ent_id_',
#  'ent_iob',
#  'ent_iob_',
#  'ent_kb_id',
#  'ent_kb_id_',
#  'ent_type',
#  'ent_type_',
#  'get_extension',
#  'has_dep',
#  'has_extension',
#  'has_head',
#  'has_morph',
#  'has_vector',
#  'head',
#  'i',
#  'idx',
#  'iob_strings',
#  'is_alpha',
#  'is_ancestor',
#  'is_ascii',
#  'is_bracket',
#  'is_currency',
#  'is_digit',
#  'is_left_punct',
#  'is_lower',
#  'is_oov',
# ...

# %%
token0.is_alpha
# Out:
# True

# %%
token1 = doc[2]
token1
# Out:
# two

# %%
token1.like_num
# Out:
# True

# %%
token2 = doc[3]
token2.text
# Out:
# '$'

# %%
token2.is_currency
# Out:
# True

# %%
with open("student.txt") as f:
    text = f.readlines()
text
# Out:
# ['Dayton high school, 8th grade students information\n',
#  '==================================================\n',
#  '\n',
#  'Name    birth day       email\n',
#  '-----   ------------    ----------------------\n',
#  'Virat   5 June, 1882    virat@kohli.com\n',
#  'Maria   12 April, 2001  maria@sharapova.com\n',
#  'Serena  24 June, 1998   serena@williams.com\n',
#  'Joe     1 May, 1997     joe@root.com']

# %%
text= ' '.join(text)
text
# Out:
# 'Dayton high school, 8th grade students information\n ==================================================\n \n Name    birth day       email\n -----   ------------    ----------------------\n Virat   5 June, 1882    virat@kohli.com\n Maria   12 April, 2001  maria@sharapova.com\n Serena  24 June, 1998   serena@williams.com\n Joe     1 May, 1997     joe@root.com'

# %% [markdown]
# Usecase

# %%
doc = nlp(text)
emails = []
for token in doc:
    if token.like_email:
        emails.append(token.text)
emails
# Out:
# ['virat@kohli.com',
#  'maria@sharapova.com',
#  'serena@williams.com',
#  'joe@root.com']

# %%
nlp = spacy.blank("hi")

doc = nlp("यह एक ₹5000 वाक्य है।")
for token in doc:
    print(token, token.like_num, token.is_currency)
# Out:
# यह False False
# एक True False
# ₹ False True
# 5000 True False
# वाक्य False False
# है False False
# । False False

# %%
doc = nlp("gimme double cheese extra large healty pizza")

token = [token.text for token in doc]
token
# Out:
# ['gimme', 'double', 'cheese', 'extra', 'large', 'healty', 'pizza']

# %%
from spacy.symbols import ORTH
nlp.tokenizer.add_special_case("gimme", [{ORTH: "gim"}, {ORTH: "me"}])

doc = nlp("gimme double cheese extra large healty pizza")
token = [token.text for token in doc]
token
# Out:
# ['gim', 'me', 'double', 'cheese', 'extra', 'large', 'healty', 'pizza']

# %%
doc = nlp("Dr.Strange is a great movie. I like it.")

for sentence in doc.sents:
    print(sentence)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 3
#       1 doc = nlp("Dr.Strange is a great movie. I like it.")
# ----> 3 for sentence in doc.sents:
#       4     print(sentence)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\spacy\tokens\doc.pyx:926, in sents()
#
# ValueError: [E030] Sentence boundaries unset. You can add the 'sentencizer' component to the pipeline with: `nlp.add_pipe('sentencizer')`. Alternatively, add the dependency parser or sentence recognizer, or set sentence boundaries by setting `doc[i].is_sent_start`.

# %%
nlp = spacy.blank("en")
nlp.add_pipe('sentencizer')

# %%
nlp.pipe_names
# Out:
# ['sentencizer']

# %%
doc = nlp("Dr.Strange is a great movie. I like it.")

for sentence in doc.sents:
    print(sentence)
# Out:
# Dr.Strange is a great movie.
# I like it.

# %% [markdown]
# Exercize

# %%
text='''
Look for data to help you address the question. Governments are good
sources because data from public research is often freely available. Good
places to start include http://www.data.gov/, and http://www.science.
gov/, and in the United Kingdom, http://data.gov.uk/.
Two of my favorite data sets are the General Social Survey at http://www3.norc.org/gss+website/, 
and the European Social Survey at http://www.europeansocialsurvey.org/.
'''

# %%
doc = nlp(text)
urls = []
for token in doc:
    if token.like_url:
        urls.append(token.text)
urls
# Out:
# ['http://www.data.gov/',
#  'http://www.science',
#  'http://data.gov.uk/.',
#  'http://www3.norc.org/gss+website/',
#  'http://www.europeansocialsurvey.org/.']

# %%
transactions = "Tony gave two $ to Peter, Bruce gave 500 € to Steve"
doc = nlp(transactions)
doc
# Out:
# Tony gave two $ to Peter, Bruce gave 500 € to Steve

# %%
token0 = doc[2]
token1 = doc[3]
token1
# Out:
# $

# %%
print(token0,token1)
# Out:
# two $
