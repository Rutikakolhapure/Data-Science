# %% [markdown]
# 1. fastText can handle OOV better than word2vec

# %% [markdown]
# 2. fastText is often a first choice when you want to train custom word embeddings for your domain

# %% [markdown]
# 3. fastTest is a technique (similar to word2vec) as well as a library
