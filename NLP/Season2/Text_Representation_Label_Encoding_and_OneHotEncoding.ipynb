# %% [markdown]
# disadvantages of One Hot Encoding

# %% [markdown]
# 1. Similar words do not have similar representation.

# %% [markdown]
# 2.Consume too much memory and compute resources

# %% [markdown]
# 3.Out Of Vocabulary problem

# %% [markdown]
# 4. No fixed length representation
