# %% [markdown]
# Word Embaddings try to address these shortcoming

# %% [markdown]
# 1. Similar words/sentences have similar vectors.

# %% [markdown]
# 2. Dimensions are low

# %% [markdown]
# Word Embadding Technique:

# %% [markdown]
# <li>1. Word2Vec</li>
# <li>2. Glove</li>
# <li>3. fastText</li>

# %% [markdown]
# The common techiniques that we use to build these word Embeaddings are Continuous Bag of Words(CBOW), Skip gram

# %% [markdown]
# Basedon transformer based techniques:
# <li>BERT</li>
# <li>GPT</li>

# %% [markdown]
# Based on LSTM:
# <li>ELMo</li>

# %% [markdown]
# Ex: King - man + woman = Queen

# %% [markdown]
# Variations based on dataset that they are trained on:
# <ol>1.GloVe</ol>
# <li>glove-wiki-gigaword-100</li>
# <li>glove-twitter-50</li>

# %% [markdown]
# 2. Word2Vec
# <li>word2vec-google-news-300</li>
# <li>word2vec-ruscopora-300</li>

# %% [markdown]
# Variations of BERT models:
# datasets on which they are trained:

# %% [markdown]
# 1.BERT:
# <li>Bio BERT</li>
# <li>Fin BERT</li>

# %% [markdown]
# Parameter tunning:

# %% [markdown]
# 2.BERT:
# <li>ALBERT</li>
# <li>RoBERTa</li>

# %% [markdown]
# The whole purpose of this these techinques is to convert the words into vectors
