# %% [markdown]
# # Bar plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
var = sns.load_dataset("penguins")
var
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
order_1=["Adelie", "Chinstrap", "Gentoo"]
sns.barplot(x="species", y="bill_length_mm", data=var,hue="sex",order=order_1,hue_order=["Female","Male"],errorbar=('ci', 100),n_boot=2,orient="v")
plt.show()

# %%
order_1=["Adelie", "Chinstrap", "Gentoo"]
sns.barplot(x="bill_depth_mm", y="bill_length_mm",data=var,orient="h",palette="icefire",saturation=0.5,ci="sd",hue="species",hue_order=order_1,errorbar=('ci', 100),n_boot=2)
plt.show()
# Out:
# C:\Users\ruchi\AppData\Local\Temp\ipykernel_22464\513036941.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(x="bill_depth_mm", y="bill_length_mm",data=var,orient="h",palette="icefire",saturation=0.5,ci="sd",hue="species",hue_order=order_1,errorbar=('ci', 100),n_boot=2)

# %%
order_1=["Adelie", "Chinstrap", "Gentoo"]
sns.barplot(x="species", y="bill_length_mm", data=var,hue="sex",order=order_1,hue_order=["Female","Male"],errorbar=('ci', 100),n_boot=2,orient="v"
            ,errwidth=10,errcolor="r")
plt.show()
# Out:
# C:\Users\ruchi\AppData\Local\Temp\ipykernel_22464\3955706393.py:2: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'r'}` instead.
#
#   sns.barplot(x="species", y="bill_length_mm", data=var,hue="sex",order=order_1,hue_order=["Female","Male"],errorbar=('ci', 100),n_boot=2,orient="v"
# C:\Users\ruchi\AppData\Local\Temp\ipykernel_22464\3955706393.py:2: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 10}` instead.
#
#   sns.barplot(x="species", y="bill_length_mm", data=var,hue="sex",order=order_1,hue_order=["Female","Male"],errorbar=('ci', 100),n_boot=2,orient="v"

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

flight_filepath =r"C:\Users\ruchi\Videos\dataset\DataSets_For_Learning/flight_delays.csv"

# Read the file into a variable flight_data
flight_data = pd.read_csv(flight_filepath, index_col="Month")

# %%
flight_data
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
# 6      8.191017 -0.220621   5.047155  4.419594  13.952793  19.712951
# 7      3.870440  0.377408   5.841454  1.204862   6.926421  14.464543
# 8      3.193907  2.503899   9.280950  0.653114   5.154422   9.175737
# 9     -1.432732 -1.813800   3.539154 -3.703377   0.851062   0.978460
# 10    -0.580930 -2.993617   3.676787 -5.011516   2.303760   0.082127
# 11     0.772630 -1.916516   1.418299 -3.175414   4.415930  11.164527
# 12     4.149684 -1.846681  13.839290  2.504595   6.685176   9.346221
#
# ...

# %%
plt.figure(figsize=(10,6))
plt.title("Average Arrival Delay for Spirit Airlines Flights, by Month")
sns.barplot(x=flight_data.index, y=flight_data['NK'],palette="Purples")
plt.ylabel("Arrival delay (in minutes)")
plt.show()
# Out:
# C:\Users\ruchi\AppData\Local\Temp\ipykernel_22464\2486316157.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=flight_data.index, y=flight_data['NK'],palette="Purples")
