# %% [markdown]
# # Histogram Plot

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

x=np.random.randint(10,60,(50))
print(x)
# Out:
# [42 13 46 48 43 33 41 12 29 46 20 56 47 33 50 50 22 24 29 27 25 53 15 17
#  18 59 33 50 54 29 42 19 17 55 39 54 48 28 55 20 46 40 43 42 36 25 14 58
#  12 36]

# %%
no=[42,13,46,48,43,33,41 ,12 ,29 ,46 ,20 ,56 ,47 ,33 ,50 ,50 ,22 ,24 ,29 ,27 ,25 ,53 ,15 ,17,
 18 ,59 ,33 ,50 ,54 ,29 ,42 ,19 ,17 ,55 ,39 ,54 ,48 ,28 ,55 ,20 ,46 ,40 ,43 ,42 ,36 ,25 ,14 ,58,
 12 ,36]
l=[10,20,30,40,50,60]
plt.hist(no,edgecolor="Black",color="Pink")

plt.title("wscubetext")
plt.xlabel("python")
plt.xlabel("no.")
plt.show()

# %%
no=[42,13,46,48,43,33,41 ,12 ,29 ,46 ,20 ,56 ,47 ,33 ,50 ,50 ,22 ,24 ,29 ,27 ,25 ,53 ,15 ,17,
 18 ,59 ,33 ,50 ,54 ,29 ,42 ,19 ,17 ,55 ,39 ,54 ,48 ,28 ,55 ,20 ,46 ,40 ,43 ,42 ,36 ,25 ,14 ,58,
 12 ,36]
l=[10,20,30,40,50,60]
plt.hist(no,bins=l,edgecolor="Black",color="Pink",rwidth=0.8,log=True)

plt.title("wscubetext")
plt.xlabel("python")
plt.xlabel("no.")
plt.show()

# %%
no=[42,13,46,48,43,33,41 ,12 ,29 ,46 ,20 ,56 ,47 ,33 ,50 ,50 ,22 ,24 ,29 ,27 ,25 ,53 ,15 ,17,
 18 ,59 ,33 ,50 ,54 ,29 ,42 ,19 ,17 ,55 ,39 ,54 ,48 ,28 ,55 ,20 ,46 ,40 ,43 ,42 ,36 ,25 ,14 ,58,
 12 ,36]
l=[10,20,30,40,50,60]
plt.hist(no,"auto",(0,100),edgecolor="Black",color="Pink",label="python")

plt.axvline(45,color="g",label="line")
plt.title("wscubetext")
plt.xlabel("python")
plt.xlabel("no.")
plt.legend()
plt.grid()
plt.show()
# Out:
# C:\Users\ruchi\AppData\Local\Temp\ipykernel_24376\1395280044.py:5: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(no,"auto",(0,100),edgecolor="Black",color="Pink",label="python")

# %%
no=[42,13,46,48,43,33,41 ,12 ,29 ,46 ,20 ,56 ,47 ,33 ,50 ,50 ,22 ,24 ,29 ,27 ,25 ,53 ,15 ,17,
 18 ,59 ,33 ,50 ,54 ,29 ,42 ,19 ,17 ,55 ,39 ,54 ,48 ,28 ,55 ,20 ,46 ,40 ,43 ,42 ,36 ,25 ,14 ,58,
 12 ,36]
l=[10,20,30,40,50,60]
plt.hist(no,edgecolor="Black",color="Pink",cumulative=1,bottom=10,align="left",histtype="step",orientation="horizontal") #cumulative=-1 for reversing
#align="mid" also can be used
#histtype="bar" or "barstacked"

plt.title("wscubetext")
plt.xlabel("python")
plt.xlabel("no.")
plt.show()
