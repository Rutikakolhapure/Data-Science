# %% [markdown]
# # Stem Plot

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4,5,6]
y=[2,2,5,4,3,3]
plt.stem(x,y,linefmt="-.",markerfmt="r+",bottom=9,basefmt="m",label="pyton",orientation="horizontal") #markerfmt="ro"
plt.legend()
plt.show()
