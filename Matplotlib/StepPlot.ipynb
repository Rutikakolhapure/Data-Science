# %% [markdown]
# # Step Plot

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4,5]
y=[3,2,3,5,4]

plt.step(x,y,color="r",marker="o",ms=10,mfc="m",label="python")
plt.legend(loc=2)
plt.grid()
plt.show()
