# %% [markdown]
# # Stack Plot

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4,5]
area1=[4,2,3,2,3]
area2=[1,3,2,4,2]
area3=[8,3,4,6,2]

l=["area1","area2","area3"]
plt.stackplot(x,area1,area2,area3,labels=l,colors=["r","g","m"],baseline="wiggle") #baseline="zero" or "sym"

plt.legend(loc=1)
plt.show()
