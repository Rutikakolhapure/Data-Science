# %%
import pandas as pd
from mlxtend.feature_selection import SequentialFeatureSelector

# %%
dataset = pd.read_csv(r"C:\Users\ruchi\Videos\dataset\DataSets_For_Learning\diabetes.csv")

# %%
dataset.head(3)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1

# %%
x = dataset.iloc[:,:-1]
y = dataset["Outcome"]

# %%
x.shape
# Out:
# (768, 8)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %% [markdown]
# #### Forward Elimination

# %%
fs = SequentialFeatureSelector(lr, k_features = 1,forward=True)
fs.fit(x,y)
# Out:
# SequentialFeatureSelector(estimator=LogisticRegression(), k_features=(1, 1),
#                           scoring='accuracy')

# %%
fs.feature_names
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age']

# %%
fs.k_feature_names_
# Out:
# ('Glucose',)

# %%
fs.k_score_
# Out:
# np.float64(0.7474747474747474)

# %%
8 - 0.7695696460402341
7 - 0.7734742381801205
6 - 0.7747899159663865 # accuracy is more
5 - 0.7708768355827178
4 - 0.7682964094728801
3 - 0.7683048977166624
2 - 0.7591206179441474
1 - 0.7474747474747474
# Out:
# 1.2408793820558526

# %% [markdown]
# #### Backward Elimination

# %%
fs = SequentialFeatureSelector(lr, k_features = 6,forward=False)
fs.fit(x,y)
# Out:
# c:\Users\ruchi\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\ruchi\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
fs.feature_names
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age']

# %%
fs.k_feature_names_
# Out:
# ('Glucose',
#  'BloodPressure',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age')

# %%
fs.k_score_
# Out:
# np.float64(0.7747729394788218)

# %%
8 = 0.7695696460402341
7 = 0.7747729394788218
6 = 0.7747729394788218
5 = 0.7708683473389355
4 = 0.7721330956625074
3 = 0.7682454800101859
2 = 0.7591206179441474
1 = 0.7474747474747474
# Out:
#   Cell In[105], line 1
#     8 = 0.7695696460402341
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?
